# %% [markdown]
# # Homework 3  - Tryout pandas and numpy
#
# Copy this notebook. Rename it as: YOURNAME-Homework-panda-numpy-Sept-2017
#
# with your name replacing yourname and  replaced with the date you submit or to the last part.
#
# Do the homeworks problems below.
#
# Upload your completed jupyter notebook to your github site and send me the url via the elearning site as your homework submission. Please note that you need to do your own 3.4, and 3.5 if you share data and analysis from others then you cannot get more than a 3.

# %% [markdown]
# ## Homework 3.1
#
# ### 3.1.a
# Load the data from: http://opendata.dc.gov/datasets that I have include in this github
# into a dataframe.  ( The file has been is available in directory ./data/ccp_current_csv.csv )

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/ccp_current_csv.csv")
data
# Out:
#                  STREET QUADRANT            FROMINTERSECTION  \
# 0               13th St       NW                  Kennedy St
# 1                  S St       NW            North Capitol St
# 2      Rhode Island Ave       NE            Brentwood Rd (W)
# 3               Mill Rd       NW                     27th St
# 4      Rhode Island Ave       NE            Brentwood Rd (M)
# 5             Mellon St       SE                      5th St
# 6          Nebraska Ave       NW              Northampton St
# 7           Military Rd       NW                     30th St
# 8          Nebraska Ave       NW                   Oliver St
# 9               16th St       NW                  Alaska Ave
# 10         Shoemaker St       NW                 Linnean Ave
# 11         Underwood St       NW             Piney Branch Rd
# 12             Elder St       NW                      7th St
# 13              26th St       NW              Northampton St
# ...

# %% [markdown]
# ### 3.1.a  what is its shape and what does that mean?

# %%
data.shape
#it tells us that how many rows and columns in the data
# Out:
# (465, 27)

# %% [markdown]
# ## Homework 3.2
#  What are the number of rows in each 'QUADRANT' ?

# %%
#465
q_id = data['QUADRANT']
data_newind = data.copy()
data_newind.index = q_id
data_newind.index.is_unique
# Out:
# False

# %%
pd.Series(data_newind.index).value_counts()
# Out:
# NW    195
# NE    163
# SE     84
# BN     12
# SW     11
# Name: QUADRANT, dtype: int64

# %% [markdown]
# ## Homework 3.3 - Array math demonstration
# For two arrarys
#
# a= [1,2,3,4]  type=float
#
# b= [5,6,7,8]  type=float
#
# Peform the following array operations using numpy
# ( show both operational use of numpy and functional (example addition operation => + vs addition function => numbpy.add() )
#
# ### 3.3.1 addition a+b

# %%
from numpy import *
a = array([1,2,3,4])
b= array([5,6,7,8])
a=np.array([1,2,3,4],dtype = np.float)
b=np.array([5,6,7,8],dtype = np.float)
print a+b
print np.add(a,b)
# Out:
# [ 6.  8. 10. 12.]
# [ 6.  8. 10. 12.]

# %%
np.add(a,b)
# Out:
# array([ 6.,  8., 10., 12.])

# %% [markdown]
# ### 3.3.2 subtraction a-b

# %%
a-b
# Out:
# array([-4., -4., -4., -4.])

# %%
np.subtract(a,b)
# Out:
# array([-4., -4., -4., -4.])

# %% [markdown]
# ### 3.3.3 multiplication a*b

# %%
a*b
# Out:
# array([ 5., 12., 21., 32.])

# %%
np.multiply(a,b)
# Out:
# array([ 5., 12., 21., 32.])

# %% [markdown]
# ### 3.3.4 divsion a/b

# %%
a/b
# Out:
# array([0.2       , 0.33333333, 0.42857143, 0.5       ])

# %%
np.divide(a,b)
# Out:
# array([0.2       , 0.33333333, 0.42857143, 0.5       ])

# %% [markdown]
# ### 3.3.5 modulo  a%b

# %%
a%b
# Out:
# array([1., 2., 3., 4.])

# %%
np.remainder(a,b)
# Out:
# array([1., 2., 3., 4.])

# %% [markdown]
# ### 3.3.6 power  a^b

# %%
a**b
# Out:
# array([1.0000e+00, 6.4000e+01, 2.1870e+03, 6.5536e+04])

# %%
np.power(a,b)
# Out:
# array([1.0000e+00, 6.4000e+01, 2.1870e+03, 6.5536e+04])

# %% [markdown]
# ## Homework 3.4
# Find your own data and load it into a dataframe

# %%
crimedata=pd.read_csv('data/Chicago_2017.csv')
print "The crime data of Chicago in 2017"
crimedata
# Out:
# I load the crime data of Chicago in 2017
#               ID Case Number                    Date  \
# 0       11094370    JA440032  09/21/2017 12:15:00 AM
# 1       11118031    JA470589  10/12/2017 07:14:00 PM
# 2       11134189    JA491697  10/30/2017 11:52:00 AM
# 3       11156462    JA521389  09/29/2017 06:45:00 PM
# 4       11164874    JA531910  12/01/2017 06:20:00 AM
# 5       10974196    JA298243  06/08/2017 04:02:00 PM
# 6       10995008    JA322389  06/25/2017 07:00:00 PM
# 7       11086755    JA430240  09/06/2017 01:30:00 PM
# 8       11157652    JA522842  11/23/2017 03:14:00 PM
# 9       11162428    JA529032  11/28/2017 09:43:00 PM
# 10      11175304    JA545986  12/11/2017 07:15:00 PM
# 11      11175934    JA546734  12/12/2017 06:00:00 PM
# 12      11230118    JB151212  11/22/2017 09:08:00 PM
# 13      11172603    JA541446  12/08/2017 03:00:00 AM
# 14      11227287    JB147188  10/08/2017 03:00:00 AM
# 15      11227293    JB147230  09/09/2017 08:17:00 PM
# ...

# %% [markdown]
# # Homework 3.5
# Provide an interesting analysis of the data columns ( frequency or averages )

# %%
#calcualte the number of crime in Chicago 2017,average crime number, frequence every 1,000 people
print "There are %d crimes in year 2017"%(len(crimedata))
print "The average crime number in 2017 is %f"%(len(crimedata)/365.0)
print "The population in Chicago is about 2.7 million, so the crime frequency every thousand people is:%f"%(len(crimedata)/2700.0)
# Out:
# There are 266974 crimes in year 2017
# The average crime number in 2017 is 731.435616
# The population in Chicago is about 2.7 million, so the crime frequency every thousand people is:98.879259

# %%
xs=crimedata['Primary Type'].value_counts()
print("Top 3 types of crime:")
print(xs[:3])
print("\nLeast 3 types of crime:")
print(xs[-3:])
# Out:
# Top 3 types of crime:
# THEFT              64221
# BATTERY            49200
# CRIMINAL DAMAGE    29027
# Name: Primary Type, dtype: int64
#
# Least 3 types of crime:
# PUBLIC INDECENCY                    10
# HUMAN TRAFFICKING                    8
# NON-CRIMINAL (SUBJECT SPECIFIED)     2
# Name: Primary Type, dtype: int64

# %%
data1=crimedata.loc[:,['Primary Type','Description','Location Description','Arrest']]
xs3=xs.sort_index() #sort all the crimes by name
xs1=data1[data1.Arrest==True] #get sub series where arrest is true
xs2=xs1['Primary Type'].value_counts()
xs2=xs2.sort_index() #sort by name
xs2/=xs3
xs2=xs2.sort_values(ascending=False) #sort by value,desending order
print "Top ten arrest rate of crimes:"
print xs2[:10]
# Out:
# Top ten arrest rate of crimes:
# LIQUOR LAW VIOLATION                 1.000000
# GAMBLING                             1.000000
# PUBLIC INDECENCY                     1.000000
# PROSTITUTION                         1.000000
# NARCOTICS                            0.999568
# CONCEALED CARRY LICENSE VIOLATION    0.956522
# INTERFERENCE WITH PUBLIC OFFICER     0.947417
# OBSCENITY                            0.827586
# WEAPONS VIOLATION                    0.783472
# PUBLIC PEACE VIOLATION               0.682031
# Name: Primary Type, dtype: float64

# %%
import matplotlib.pyplot as plt
crimedata=pd.read_csv('data/Chicago_2017.csv',usecols=['Date','Domestic'],parse_dates=['Date'])
month=crimedata.Date.dt.month  #get month
his=crimedata['Domestic'].groupby(month).sum()  #get sum for 'Domestic' true and false
his2=hour.groupby(month).size()  #sum as a whole
his2=his/his2
his2=his2.reset_index()
his2.columns=['Month','Domestic Propotion']
print "This is a plot where the x-axis is Month and the y-axis is the proportion of crimes occuring that are domestic"
# %matplotlib inline
his2.plot(x='Month',y='Domestic Propotion',kind='line')
# Out:
# This is a plot where the x-axis is Month and the y-axis is the proportion of crimes occuring that are domestic

# %%
print "The number of crime in each month:"
crimedata.Date.dt.month.hist(bins=12)
# Out:
# The number of crime in each month:

# %%
print "The number of crime in each hour:"
crimedata.Date.dt.hour.hist(bins=24)
# Out:
# The number of crime in each hour:
